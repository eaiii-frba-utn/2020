# %% [markdown]
# # Electrónica Aplicada III
#
# Carga Horaria total. Hs Reloj-128 (CIENTO VEINTIOCHO)-Hs. Cátedra-160-(CIENTO SESENTA)
#
# ## FUNDAMENTACIÓN
#
# Ante la necesidad de:
#
# Realizar, el análisis, la síntesis e interrelación de los circuitos que componen los Sistemas de
# Transmisión y Recepción en RF, ver su comportamiento en detalle y el de cada una de las etapas que lo
# componen, a fin de obtener una cabal comprensión de su funcionamiento.
#
# Robustecer la enseñanza de conceptos que serán válidos con independencia de las soluciones
# tecnológicas particulares permitiéndole al futuro graduado adaptarse a los cambios que se gesten durante
# su vida profesional, la que ha de ser contemplada con un adecuado análisis de casos prácticos que permitan
# al cursante acortar la distancia que media entre el cálculo teórico y su concreción real.
#
# Se considera entonces, que en la currícula haya una materia, que asocie la rama de las materias de
# electrónicas aplicadas, con la rama de comunicaciones, de ahí el por qué de la existencia de Electrónica
# Aplicada III
#
#
# ## PROGRAMA
#
# ### Primer Cuatrimestre:
#     Circuitos de Adaptación
#     Amplificadores Sintonizados
#     Amplificador Pasabanda Real
#     Detector de AM y AGC
#     Ruido
#
# ### Segundo Cuatrimestre:
#     Amplificador Clase C
#     Osciladores
#     Mezcladores
#     Modulación Angular (Generación y detección)
#     PLL
#     BLU / Amplificadores de Alto Rendimiento
#
#
#
# # Cronograma
# | Fecha Lunes | Fecha Jueves | Cronograma tentativo     | Practica de laboratorio           | Entragas problemas          | Proyecto                     |
# |-------------|--------------|--------------------------|-----------------------------------|-----------------------------|------------------------------|
# | 30/3        | 2/4          | Introducción             |                                   |                             |                              |
# |             |              | Circuitos de Adaptación  |                                   |                             |                              |
# |             |              | Circuitos de Adaptación  |                                   |                             |                              |
# |             |              | Circuitos de Adaptación  | Filtros                           | Circuitos de Adaptación     |                              |
# |             |              | Circuitos Sintonizados   |                                   |                             |                              |
# |             |              | Circuitos Sintonizados   |                                   |                             |                              |
# |             |              | Circuitos Sintonizados   |                                   |                             |                              |
# |             |              | Circuitos Sintonizados   |                                   | Sintonizados                |                              |
# |             |              | Estabilidad              |                                   |                             |                              |
# |             |              | Estabilidad              |                                   |                             |                              |
# |             |              | Estabilidad              |                                   | Estabilidad                 |                              |
# |             |              | Ruido                    |                                   |                             |                              |
# |             |              | Ruido                    | Amplificador bajo Ruido           |                             |                              |
# |             |              | Repaso, problemas        |                                   | Ruido                       | Entraga informe simulaciones |
# |             |              | 1° Parcial               |                                   |                             |                              |
# |             |              | Clase C                  |                                   |                             |                              |
# |             |              | Clase C                  |                                   |                             |                              |
# |             |              | Clase C                  |                                   | Clase C                     |                              |
# |             |              | Clase C                  | Amplificador Potencia             |                             |                              |
# |             |              | PLL                      |                                   |                             |                              |
# |             |              | Osciladores              |                                   | Clase C                     |                              |
# |             |              | Osciladores              |                                   |                             |                              |
# |             |              | Mezcladores e IDM        |                                   |                             |                              |
# |             |              | Mezcladores e IDM        | Mezclador y Oscilador             |                             |                              |
# |             |              | Modulacion angular       |                                   | Osciladores y mezcladores   | Feria de proyectos           |
# |             |              | Demodulación angular     |                                   |                             | Feria de proyectos           |
# |             |              | Alta eficiencia          |                                   |                             | Feria de proyectos           |
# |             |              | Repaso, problemas        |                                   | Moduladores y demoduladores |                              |
# |             |              | 2 Parcial                |                                   |                             |                              |

# %% [markdown]
# # Condiciones para la firma
#
# ### Aprobar los dos parciales (6 o mas puntos), dos recuperatorios por parcial.
#
# ### Completar las entregas de practicas obligatorias.
#
#
# # Condiciones para promoción
#
# ### Aprobar los dos parciales (sumatoria de los parciales mayor o igual a 15 y nota del segundo parcial mayor o igual a 8), dos recuperatorios por parcial, un solo recuperatorio en diciembre.
#
#
# ### Completar las entregas de practicas obligatorias.
#
# ### Proyecto
#
# [Listado de proyectos propuestos para este año](./12_Proyecto/1_Introduccion/Listado_de_propuestas_para_proyectos.ipynb)
#
#
# #### De realización grupal  y  entrega individual
#
# #### Dos entregas obligatorias (siempre antes del parcial)
#
#     Primera entrega:  Informe de desarrollo teorico y calculos.
#
#     Segunda entrega: Informe de proyecto, componentes, diseño PCB, etc, y Presentación Oral en Feria de proyecto (10 min).
#
#
# #### NOTA: las entregas no tiene recuperatorios, de no efectuar la entrega se pierde la condición de promoción. Solo se permiten corrección al informe.
#
# #### El seguimiento se realizara con carpetas compartidas que deben ser actualizadas periodicametnte. Sobre el avance se realizaran consultas a los integrantes del proyectos.
#
# #### La entrega es responsabilidad del alumno, no es una exigencia de los profesores.
