# %% [markdown]
# # Algunos componentes disponibles
#
#
# # Filtro
#
# ### 1. [A Low-Cost Surface Mount PIN Diode π Attenuator](./NotasTecnicas/AN1048.pdf)
#
#
# ### 2. [Tunable Bandpass Filters](https://www.am1.us/product/tunable-bpfs/)
#     20 MHz to 40 MHz
#     40 MHz to 80 MHz
#     160 MHz to 320 MHz
#     320 MHz to 640 MHz
#
# # LNA
#
# ### 3. BFU550A ISM 433 o 866 MHz LNA design
#
# 100 568-11514-1-ND https://www.nxp.com/docs/en/data-sheet/BFU550A.pdf
#
#
# #### 4. [BFU550A ISM 433 MHz LNA design](https://www.nxp.com/docs/en/application-note/AN11381.pdf)
#
# #### 5. [BFU550A ISM 866 MHz LNA design](https://www.nxp.com/docs/en/application-note/AN11382.pdf)
#
#
# ### LNA 900MHz RF
#
# 100 MBC13916NT1CT-ND https://www.nxp.com/docs/en/data-sheet/MBC13916.pdf
#
# #### 6. [ LNA 900MHz RF BiCMOS process using the SiGe:C module.](https://www.mouser.es/datasheet/2/302/MBC13916-1126543.pdf)
#
# ### DAB band-III Amplifier Using the MCH4015
#
# 20	MCH4015-TL-HOSCT-ND https://www.onsemi.com/pub/Collateral/MCH4015-D.PDF
# #### 7. [DAB band-III Amplifier Using the MCH4015 ](https://www.onsemi.com/pub/Collateral/ANDMCH4015_1-D.PDF)
#
#
# ### BFP460 FM antenna LNA for 76 to 108MH
#
# #### 8. [BFP460 FM antenna LNA for 76 to 108MH](https://www.infineon.com/cms/en/product/rf-wireless-control/rf-transistor/low-noise-si-transistors-up-to-5-ghz/bfp460/)
# 50 BFP460H6327XTSA1CT-ND
#
#
# ## VCO
# 10  MAX2609EUT+T-ND   https://www.mouser.com/datasheet/2/256/MAX2605-MAX2609-1515582.pdf
#
# ### 9. [The MAX2609 evaluation kits (EV kits) simplify evaluation of this family of voltage-controlled oscillators (VCOs).](https://www.maximintegrated.com/en/products/comms/wireless-rf/MAX2607EVKIT.html/tb_tab2)
#
#
#
# ## Mixer
# 10 MAX2682EUT+TCT-ND https://datasheets.maximintegrated.com/en/ds/MAX2680-MAX2682.pdf
#
# ### 10. [The MAX2682 evaluation kits (EV kits) simplify the evaluation of the MAX2682 downconverter mixers.](https://datasheets.maximintegrated.com/en/ds/MAX2680EVKIT-MAX2682EVKIT.pdf)
#
# ### 11. [Active Mixer Design Using the NE25139](./NotasTecnicas/an1020.pdf)
#
#
#
# ## Oscillator
#
# 10 MAX2620EUA+-ND    https://datasheets.maximintegrated.com/en/ds/MAX2620.pdf
#
# ### 12. [The MAX2620 evaluation kit (EV kit) simplifies evaluation of the MAX2620 integrated oscillator with buffered outputs.](https://www.maximintegrated.com/en/products/comms/wireless-rf/MAX2620EVKIT.html/tb_tab2)
#
# ### 13. [A 1GHz discrete VCO based on the BFR92A](./NotasTecnicas/AN11225.pdf)
#
# ### 14. [Applying the oscillator of the SA602A in low-power mixer applications](./NotasTecnicas/AN1982.pdf)
#
#
# ## FM system
#
# 10 568-4327-1-ND https://www.nxp.com/docs/en/data-sheet/SA636.pdf
#
# ### 15. [Low voltage high performance mixer FM IF system with high-speed RSS](https://www.nxp.com/docs/en/data-sheet/SA636.pdf)
#
#
#
#
#
# ## Power RF amplifier
#
# 16. PD85004: RF power transistor POUT = 4 W with 17 dB gain @ 870 MHz
#
# https://www.st.com/content/ccc/resource/technical/document/datasheet/ec/56/e5/b3/69/ca/4d/d7/CD00178461.pdf/files/CD00178461.pdf/jcr:content/translations/en.CD00178461.pdf
#
#
# 17. RD01MUS2 : MOSFET Power Transistor 520MHz, 1W, 7.2V
#
#
# https://articulo.mercadolibre.com.ar/MLA-736624552-rd-01mus2-rd-01mus2-rd01mus2-k5-611-transistor-mosfet-rf-1w-_JM?quantity=1#position=5&type=item&tracking_id=cb911639-18ad-4905-8e0e-6a8fd9316d70
#
# http://www.mitsubishielectric.com/semiconductors/content/product/highfrequency/siliconrf/discrete/rd01mus2b.pdf
#
# 18. MRF134: The RF MOSFET Line: Broadband RF Power FET 5.0W
#
# https://articulo.mercadolibre.com.ar/MLA-663757538-transistor-mrf134-nuevos-en-blister-_JM?quantity=1#position=2&type=item&tracking_id=29a1ce2a-2427-47b7-ab49-83e0163737c0
#
#
#
# https://www.vishay.com/docs/70628/70628.pdf

# %% [markdown]
# ### [AN1670: 60 Watts, GSM 900 MHz, LDMOSTwo--Stage Amplifier](./NotasTecnicas/AN1670.pdf)
#
# ### [Practical Approach Yields Class-C PA](./NotasTecnicas/Firas_2006_6.pdf)

# %% [markdown]
# 10  568-1202-5-ND https://www.nxp.com/docs/en/data-sheet/SA604A.pdf
#
# 100 568-12530-1-ND https://www.nxp.com/docs/en/data-sheet/BF1105_R_WR.pdf
#
# 100 MMBT918CT-ND https://media.digikey.com/pdf/Data%20Sheets/ON%20Semiconductor%20PDFs/PN918,%20MMBT918.pdf
#
# 20	568-1965-6-ND https://www.digikey.com/product-detail/en/nxp-usa-inc/BF511215/568-1965-1-ND/807561
#
# 20	568-1971-1-ND https://media.digikey.com/pdf/Data%20Sheets/NXP%20PDFs/BF992.pdf
#
# 14	568-6541-1-ND https://media.digikey.com/pdf/Data%20Sheets/NXP%20PDFs/PRF947.pdf
#
# 10	568-1992-6-ND https://www.nxp.com/docs/en/data-sheet/BFT25A.pdf
