# %% [markdown]
# # Algunos componentes disponibles
#
#
#
# # 1. Atenuador con diodos PIN
#
# [A Low-Cost Surface Mount PIN Diode π Attenuator](./NotasTecnicas/AN1048.pdf)
#
# # 2. Filtro de sintonia Variable
#
# [Tunable Bandpass Filters](https://www.am1.us/product/tunable-bpfs/)
#
# [U24143_Tunable_BPF_Part_I](https://www.am1.us/wp-content/uploads/Documents/U24143_Tunable_BPF_Part_I.pdf)
#
# [U24143_Tunable_BPF_Part_II](https://www.am1.us/wp-content/uploads/Documents/U24143_Tunable_BPF_Part_II.pdf)
#
# [U24143_Tunable_BPF_Part_III](https://www.am1.us/wp-content/uploads/Documents/U24143_Tunable_BPF_Part_III.pdf)
#
#     20 MHz to 40 MHz
#     40 MHz to 80 MHz
#     160 MHz to 320 MHz
#     320 MHz to 640 MHz
#
# # 3. LNA NPN BFU550: 433 MHz o 866 MHz
#
# 100 568-11514-1-ND https://www.nxp.com/docs/en/data-sheet/BFU550A.pdf
#
# [BFU550A ISM 433 MHz LNA design](https://www.nxp.com/docs/en/application-note/AN11381.pdf)
#
# [BFU550A ISM 866 MHz LNA design](https://www.nxp.com/docs/en/application-note/AN11382.pdf)
#
# # 4. LNA Cascode MBC13916:  900 MHz
#
# 100 MBC13916NT1CT-ND https://www.nxp.com/docs/en/data-sheet/MBC13916.pdf
#
# [LNA 900MHz RF BiCMOS process using the SiGe:C module.](https://www.mouser.es/datasheet/2/302/MBC13916-1126543.pdf)
#
#
# # 5. LNA NPN SiGe 200 MHz
#
# 20	MCH4015-TL-HOSCT-ND https://www.onsemi.com/pub/Collateral/MCH4015-D.PDF
#
# [DAB band-III Amplifier Using the MCH4015](https://www.onsemi.com/pub/Collateral/ANDMCH4015_1-D.PDF)
#
#
# # 6. LNA NPN FM antenna alta impedancia entrada
#
# 50 BFP460H6327XTSA1CT-ND   https://www.infineon.com/cms/en/product/rf-wireless-control/rf-transistor/low-noise-si-transistors-up-to-5-ghz/bfp460/
#
# BFP460 FM antenna LNA for 76 to 108MH: FM antenna LNAs matched to high impedance at the inpu
#
# https://www.infineon.com/dgdl/Infineon-AN_1806_PL32_1808_171123_Desing%20guide%20for%20low%20noise%20TR-AN-v01_00-EN.pdf?fileId=5546d46265f064ff016643d95d931033
#
# https://www.infineon.com/cms/en/product/rf-wireless-control/rf-transistor/low-noise-si-transistors-up-to-5-ghz/bfp460/)
#
#
#
# # 7. VCO discrete 1GHz  based on the BFR92A
#
# [A 1GHz discrete VCO based on the BFR92A](./NotasTecnicas/AN11225.pdf)
#
#
#
# # 8. Active Mixer Design
#
# https://hackaday.com/2018/06/11/understanding-a-mosfet-mixer/
#
# 100 568-12530-1-ND https://www.nxp.com/docs/en/data-sheet/BF1105_R_WR.pdf
#
# [Active Mixer Design Using the NE25139](./NotasTecnicas/an1020.pdf)
#
#
#
# # 9. Downconverter mixers MAX2682
#
# 10 MAX2682EUT+TCT-ND https://datasheets.maximintegrated.com/en/ds/MAX2680-MAX2682.pdf
#
# [The MAX2682 evaluation kits (EV kits) simplify the evaluation of the MAX2682 downconverter mixers.](https://datasheets.maximintegrated.com/en/ds/MAX2680EVKIT-MAX2682EVKIT.pdf)
#
#
# # 10. Oscillator 900 MHz
#
# 10 MAX2620EUA+-ND    https://datasheets.maximintegrated.com/en/ds/MAX2620.pdf
#
# [The MAX2620 evaluation kit (EV kit) simplifies evaluation of the MAX2620 integrated oscillator with buffered outputs.](https://www.maximintegrated.com/en/products/comms/wireless-rf/MAX2620EVKIT.html/tb_tab2)
#
#
#
#
# ## 11. FM system
#
# 10 568-4327-1-ND https://www.nxp.com/docs/en/data-sheet/SA636.pdf
#
# [Low voltage high performance mixer FM IF system with high-speed RSS](https://www.nxp.com/docs/en/data-sheet/SA636.pdf)
#
#
# # 12. Power RF amplifier  MOSFET 520MHz, 1W, RD01MUS2
#
#
# https://articulo.mercadolibre.com.ar/MLA-736624552-rd-01mus2-rd-01mus2-rd01mus2-k5-611-transistor-mosfet-rf-1w-_JM?quantity=1#position=5&type=item&tracking_id=cb911639-18ad-4905-8e0e-6a8fd9316d70
#
# http://www.mitsubishielectric.com/semiconductors/content/product/highfrequency/siliconrf/discrete/rd01mus2b.pdf
#
#
# # 13. Power RF amplifier  MRF134: The RF MOSFET Line: Broadband RF Power FET 5.0W
#
# https://articulo.mercadolibre.com.ar/MLA-663757538-transistor-mrf134-nuevos-en-blister-_JM?quantity=1#position=2&type=item&tracking_id=29a1ce2a-2427-47b7-ab49-83e0163737c0
#
#
# # 14. Power RF amplifier 8W / 400 - 500 MHz evaluation board based on PD55008-E
#
# https://www.st.com/content/st_com/en/products/evaluation-tools/product-evaluation-tools/rf-power-transistor-eval-boards/steval-tdr014v1.html
#
# # 15. Power RF amplifier 4 W / 380 - 512 MHz reference design using PD84001 + PD54003L-E + LPF
#
# https://www.st.com/content/st_com/en/products/evaluation-tools/product-evaluation-tools/rf-power-transistor-eval-boards/steval-tdr001v1.html
#
# # 16. Power RF amplifier 4 W with 17 dB gain @ 870 MHz, PD85004
#
#
# https://www.st.com/content/ccc/resource/technical/document/datasheet/ec/56/e5/b3/69/ca/4d/d7/CD00178461.pdf/files/CD00178461.pdf/jcr:content/translations/en.CD00178461.pdf
