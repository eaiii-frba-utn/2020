# %% [markdown]
# ![ejemplo2g-cuatrocientos](fig/ejercicio3g.png)
#
#
# El circuito de la figura corresponde a un receptor de Broadcasting AM ($550 KHz$ a $1,6 MHz$).
#
# Está sintonizado para recibir un canal de $F_c = 600 KHz$ modulado al 50\%  por un tono único de $3\,KHz$.
#
# Todos los elementos activos (Amplificadores, mezclador y detector) son lineales y de parámetros constantes dentro de toda la banda de interés con lo que :
#
#
#
# $Y_{11} = (1 + j0) mS$
#
# $Y_{22} = (0,1 + j0) mS$
#
# $Y_{12} = 0 mS$
#
#
#
# ![ejemplo2g-cuatrocientos](fig/ejercicio3g2.png)
#
#
#
# Ambos amplificadores (RF y FI) son sincrónicos.
#
# $$F_{ol} = F_{c} + 455 KHz$, $F_{FI}= 455 KHz$$
#
# La antena presenta una impedancia $R_{a}= 50 \Omega$ en toda la banda de interés (550 KHz - 1.6 MHz).
#
# Todos los tanques están adaptados a MTE Q cte.
#
# Las bobinas empleadas para el amplificador de RF poseen : $Q_{oL} = 100$ y $N = 100$ espiras.
#
# Las bobinas empleadas para el amplificador de FI poseen : $Q_{oL} = 200$.
#
# Capacitores con $Q_{oL} = \infty$.
#
# Rechazo de frecuencia imagen  $\mid A_{@f_{Img}} \mid = 80 dB$.
#
# Rechazo de canal adyacente  $\mid A_{@f_{c}\pm50KHz} \mid = 90 dB$.

# %% [markdown]
# Determinar:
#
# 1. $Q_{c}$ para la etapa de RF
#
# 2. $L_1$
#
# 3. $C_1$
#
# 4. $N_1/N_t$
#
# 5. $N_2/N_t$
#
# 6. $N_3/N_t$
#
# 7. Calcular el ancho de banda $BW$ del amplificador de RF.
#
# 8. Calcular la ganacia de tensión de la etapa de RF.
#
# 7. $Q_{c}$ para la etapa de FI.
#
# 8. $L_2$
#
# 9. $C_2$
#
# 10. $C_3$
#
# 11. Calcular el ancho de banda $BW$ del amplificador de RF.
#
# 12. Calcular la ganacia de tensión de la etapa de RF.
#
#
# 13. Con el receptor en su condición original ($f_{c} = 600 KHz$) una falla en el Oscilador Local hace que la frecuencia del mismo se corra a $f'_{ol} = 1070 Khz$.
#
# Encontrar el índice de modulación (m) de la señal a la entrada del detector (Vo) siendo  $m = \frac {V_{pico} - V_{valle}}{V_{pico} + V_{valle}}$.
#
#
# 14. Se re-sintoniza a $F_{rf} = 1600 KHz$.
#
# Calcular el rechazo variando solamente $C_1$ y manteniendo constante $L_1$
#
# 15. Se re-sintoniza a $F_{rf} = 1600 KHz$.
#
# Calcular el rechazo variando solamente $L_1$ y manteniendo constante $C_1$, comparar con el resultado anterior.
