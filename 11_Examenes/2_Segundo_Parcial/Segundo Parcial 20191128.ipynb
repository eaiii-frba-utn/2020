# %% [markdown]
# # Segundo Parcial: Clase C exitado con AM.
#
#
# La transferencia del transistor se define en la funcion idi(v).
#
#
# ![ex 2.13](fig/parcial20192811e1.png)
#
#
# Dado el amplificador de la figura, diseñar para máxima excursión de salida siendo:
#
#
#
# $V_{g}= V_s \cdot (1+m \cdot cos(w_{m}. t)) \cdot \cos(w_{o} \cdot t) [V]$
#
# $f_{o}= 1 MHz$
#
# $f_{m}= 1 KHz$
#
# $m= 0.7$
#
#
#
#
# $V_{DD}=110 V$
#
#
# El tanque PI opera a $Q_c= 10$, sus componentes no tienen perdidas  resuena a $f_o= 10 MHz$ reflejando sobre el Drain una resistencia pura ($X= 0$) de valor $R_c$.
# En el pico positivo de la modulación el amplificador opera con un ángulo de circulación de corriente de Drain de $\theta = 160$
#
#
# |Symbol        | Parameter                  | Value | Unit |
# |--------------|----------------------------|-------|------|
# |$V_{(BR)DSS}$ |  Drain source voltage      | 250   | V    |
# |$V_{GS}     $ |  Gate source voltage       | 100   | V    |
# |$I_{D}      $ |  Drain current             | 10    | A    |
# |$V_{(min)DS}$ |  Drain source voltage min. | 10    | V    |
#
# ![ex 2.13](fig/parcial20192811e2b.png)
#
# Exitación, polarización y carga entán diseñados par que el amplificador entregue máxima potancia sobre la carga.
#
# Determinar
#
# 1.	$V_{GG}$ y $V_s$
# 2. 	$R_c$
# 3. 	PEP:  Potencia pico de envolvente sobre RL.
# 4.  Angulo de circulación en condicón de portadora  y de valle.
# 5.  Indice de modulación a la salida ($m = \frac{V_{pico} - V_{valle} }{V_{pico} + V_{valle}}$)
# 6.  Potencia en la carga ($P_{AM}$), potencia entregada por la fuente ($P_{DC}$) y potencia disipada en el mosfet ($P_{MOSFET}$).
# 7. 	Se reduce $V_{DD} = 90V$. Sin modificar el filtro de salida, determinar el valor de PEPsi se pretende un indice de modulación del 100 porciento, sin recortes de envolvente.
# 8. 	En las condiciones del ítem 7, determinar $V_{GG}$  si se mantiene constante $V_s$.

# %% [markdown]
# # 1 $V_{GG}$ y $V_s$
#
# Se busca máxima excursión de la corriente de salida, por lo tanto, en la condición de pico $V_{GG}$ y $V_{s}$ deben sumar $10 V$
#
# $V_{GG} +  V_s \cdot cos(0) = 10V$
#
#
# El ángulo de conducción debe ser de $160$, por lo tanto, considerando $V_s(\theta) = V_s \cdot cos(\theta)$, cuando $\theta = \frac{160}{2}$, la suma de  $V_{GG}$ y $V_{s}(\frac{160}{2})$ debe ser cero.
#
#
# $V_{GG} +  V_s \cdot cos(\frac{160}{2}) = 0V$
#
#
# Entonces, resolviendo:
#
# $V_s = 7.11 V$
#
# $V_{GG} = -2.10V$

# %% [markdown]
# # 2 RC
#
# Para conocer Rc se necesita conocer la corriente máxima producida por el pico de la portadora
#
# El calculo de $Rc$ debe realizarce en la condición de máxima corriente, o sea, en la condición de pico de la señal AM. Del pulso de corriente de Drain es necesario conocer la componente fundamental, que corresponde a la frecuencia de sintonia del filtro de salida ($10 MHz$). Las componentes de mayor frecuencia son multiplos de la fundamental y son atenuadas por el filtro.
#
# En esta condición, la excusión de la tensión en el Drain debe ser la máxima, o sea,
#
# $V_{DD} - V_{DSmin} = 110 V - 10 V = 100 V$
#
#
# El pulso de corriente en condición de pico:
#
# ![ex 2.13](fig/parcial20192811p1.png)
#
# ## Calculo del espectro del pulso de corriente de Drain en condición de pico.
#
# |th      |vgs      |ids      |ids.cos(th)|
# |--------|---------|---------|-----------|
# |    0.00|    10.00|    10.00|      10.00|
# |   15.00|     9.59|     9.59|       9.26|
# |   30.00|     8.38|     8.38|       7.26|
# |   45.00|     6.46|     6.46|       4.56|
# |   60.00|     3.95|     3.95|       1.97|
# |   75.00|     1.03|     1.03|       0.27|
# |   90.00|    -2.10|     0.00|      -0.00|
# |  105.00|    -5.23|     0.00|      -0.00|
# |  120.00|    -8.15|     0.00|      -0.00|
# |  135.00|   -10.66|     0.00|      -0.00|
# |  150.00|   -12.58|     0.00|      -0.00|
# |  165.00|   -13.79|     0.00|      -0.00|
#
#
#
# ###   Componente de continua $I_{dop}$ (condición de pico)
#
# $I_{do} = \frac{1}{n} \sum_{i=1}^{n} idc_1(\theta_m(i))$
#
# donde $n$ es el número de muestras.
#
# Se propone emplear $n = 24$, lo que corresponde a muestras cada $15$ grados.
#
# Por el metodo de los trapecios, primero obtenemos la tabla para 24 muestras.
# La ecuación puede simplificarse a por su simetria par, teniendo en cuenta que en este caso, la primer muestra debe dividirse por 2.
#
# $I_{do} = \frac{1}{12}  [ \frac{idc_1(\theta_m(1))}{2} + \sum_{i=2}^{\frac{n}{2}} idc_1(\theta_m(i)) ]$
#
# Entonces, aplicando metodo de los trapecios:
#
# $I_{do} = \frac{1}{12} [ \frac{i_d(0)}{2} +i_d(15) +i_d(30) +i_d(45)+ i_d(60) +i_d(75) + i_d(90)  ]$
#
# $I_{do} = \frac{1}{12} [ \frac{10}{2} +9.59 +8.38 +6.46 + 3.95 + 1.03] = 2.87 A$
#
#
#
# ###   Componente de fundamental $I_{d1}$ (condición de pico)
#
# $I_{d1} = \frac{2}{n}   [ \sum_{i=1}^{n} idc_1(\theta_m(i)) \cdot cos(\theta_m(i) \cdot 1)]$
#
#
# donde n es el número de muestras.
#
# Por el metodo de los trapecios, primero obtenemos la tabla para 24 muestras.
#
# La ecuación puede simplificarse a por su simetria par:
#
# $I_{d1} = \frac{1}{6} [ \frac{idc_1(\theta_m(1))}{2} + \sum_{i=2}^{\frac{n}{2}} idc_1(\theta_m(i)) \cdot cos(\theta_m(i))]$
#
# Aplicando metodo de los trapecios:
#
# $I_{d1} = \frac{1}{6} [ \frac{id(0)}{2} +id(15)\cdot cos(15) +id(30) \cdot cos(30) +id(45) \cdot cos(45)+ id(60) \cdot cos(60) +id(75) \cdot cos(75) + id(90) \cdot cos(90)  ]$
#
# $I_{d1} = \frac{1}{6} [ \frac{10}{2} +9.26 +7.26 +4.56 + 1.97+ 0.27] =4.72 A$
#
#
# ### Calculo de Rc
#
#
# $R_{c} = \frac{V_{DD} - V_{DSmin} }{I_{d1} }   =   21.18 ohm$

# %% [markdown]
# # 3. PEP: Potencia pico de envolvente sobre RL
#
# $P_{EP} = \frac{ I_{d1}^2 \cdot R_c}{2}   = 236 W$

# %% [markdown]
# # 4.  Angulo de circulación en condicón de portadora  y de valle.
#
# ## Angulo de circulación en condicion de portadora
#
#
# En la condición de valle la señal de AM en vgs es:
#
# $V_{gs}= 7.1 \cdot (1  ) \cdot \cos(w_{o} \cdot t) + V_{GG} [V]$
#
#
# $V_{gs}=  7.11 \cdot \cos(\theta) - 2.1 [V]$
#
# El angulo de circulación entonces,
#
# $0 =  7.11 \cdot \cos(\frac{\theta_c}{2}) - 2.1 [V]$
#
# $\theta_c =  145.6$
#
# ## Angulo de circulación en condicion de valle
#
# En la condición de valle la señal de AM en vgs es:
#
# $V_{gs}= 7.1 \cdot (1 - 0.7 ) \cdot \cos(w_{o} \cdot t) + V_{GG} [V]$
#
#
# $V_{gs}=  2.133 \cdot \cos(\theta) - 2.1 [V]$
#
# El angulo de circulación entonces,
#
# $0 =  2.133 \cdot \cos(\frac{\theta_c}{2}) - 2.1 [V]$
#
# $\theta_c =  20.183$

# %% [markdown]
# # 5.  Indice de modulación a la salida ($m = \frac{V_{pico} - V_{valle} }{V_{pico} + V_{valle}}$)
#
#
#
# ## Corriente de salida en condición de valle
#
#
# ![ex 2.13](fig/parcial20192811p2.png)
#
# |th      |vgs      |ids      |ids.cos(th)|
# |--------|---------|---------|-----------|
# |    0.00|     0.03|     0.03|       0.03|
# |   15.00|    -0.04|     0.00|       0.00|
# |   30.00|    -0.25|     0.00|       0.00|
# |   45.00|    -0.59|     0.00|       0.00|
# |   60.00|    -1.03|     0.00|       0.00|
# |   75.00|    -1.55|     0.00|       0.00|
# |   90.00|    -2.10|     0.00|      -0.00|
# |  105.00|    -2.65|     0.00|      -0.00|
# |  120.00|    -3.17|     0.00|      -0.00|
# |  135.00|    -3.61|     0.00|      -0.00|
# |  150.00|    -3.95|     0.00|      -0.00|
# |  165.00|    -4.16|     0.00|      -0.00|
#
#
#
#
# ###   Componente de continua $I_{do}$ (condición de valle)
#
#
# Aplicando metodo de los trapecios:
#
# $I_{do} = \frac{1}{12} [ \frac{i_d(0)}{2} ]$
#
# $I_{do} = \frac{1}{12} [ \frac{0.03}{2} ] = 0.03 A$
#
#
#
# ###   Componente de fundamental $I_{d1}$ (condición de valle)
#
#
# Aplicando metodo de los trapecios:
#
# $I_{d1v} = \frac{1}{6} [ \frac{id(0)}{2}  ]$
#
#
# $I_{d1v} = \frac{1}{6} [ \frac{0.03}{2} ] =0.0 A$
#
#
# $V_{Rcvalle} = I_{d1v} \cdot R_c   =   0.0 V$
#
#
# $V_{Rcpico} = I_{d1p} \cdot R_c   =   100.0 V$
#
#
# ## Indice de modulación
#
#
#
# $m = \frac{V_{Rcpico} - V_{Rcvalle}}{V_{Rcpico} +V_{Rcvalle}} = 0.998$

# %% [markdown]
# # 6.  Potencia en la carga, $P_{DC}$, $P_{MOSFET}$
#
#
# ![ex 2.13](fig/parcial20192811p3.png)
#
#
# ## Corriente de salida en condición de portadora
#
#
# |th      |vgs      |ids      |ids.cos(th)|
# |--------|---------|---------|-----------|
# |    0.00|     5.02|     5.02|       5.02|
# |   15.00|     4.77|     4.77|       4.61|
# |   30.00|     4.06|     4.06|       3.52|
# |   45.00|     2.93|     2.93|       2.07|
# |   60.00|     1.46|     1.46|       0.73|
# |   75.00|    -0.26|     0.00|       0.00|
# |   90.00|    -2.10|     0.00|       0.00|
# |  105.00|    -3.94|     0.00|       0.00|
# |  120.00|    -5.66|     0.00|       0.00|
# |  135.00|    -7.13|     0.00|       0.00|
# |  150.00|    -8.27|     0.00|       0.00|
# |  165.00|    -8.98|     0.00|       0.00|
#
#
# idco= 1.31 A, idc1=2.24 A
#
# ###   Componente de continua $I_{do}$ (condición de portadora)
#
#
# Aplicando metodo de los trapecios:
#
# $I_{do} = \frac{1}{12} [ \frac{i_d(0)}{2} +i_d(15) +i_d(30) +i_d(45)+ i_d(60)  ]$
#
# $I_{do} = \frac{1}{12} [ \frac{5.02}{2} +4.77 +4.06 +2.93 +1.46 ] = 1.31 A$
#
#
# ###   Componente de fundamental $I_{d1}$ (condición de portadora)
#
#
# Aplicando metodo de los trapecios:
#
# $I_{d1c} = \frac{1}{6} [ \frac{id(0)}{2} +id(15)\cdot cos(15) +id(30) \cdot cos(30) +id(45) \cdot cos(45)+ id(60) \cdot cos(60) ]$
#
#
# $I_{d1c} = \frac{1}{6} [ \frac{5.02}{2} +4.61 +3.52 +2.07 + 0.73] =2.24 A$
#
#
#
# ## Para conocer el espectro de la señal de salida
#
# La señal de la portadora vale
#
# $V_{Rc} = I_{d1c} \cdot R_c   =   47.45 V$
#
# Esta señal esta modulada por una modulante de la que conocemos $4$ puntos (cada $90$ grados).
#
#
# |$th$    |$i_{do}(th)$|$i_{d1}(th)$   |
# |--------|------------|---------------|
# |  0     | 2.866 A    |4.720  A       |
# | 90     | 1.311 A    |2.240  A       |
# |180     | 0.001 A    |0.002  A       |
# |270     | 1.311 A    |2.240  A       |
#
#
# ### Potencia de DC
#
# La componente de continua $i_{do}$ varia con el tiempo, por lo tanto tiene una componente de continua y una alterna de baja frecuencia. Para concer estas señales podemos emplear Fourier
#
#
# $I_{DCo} = \frac{1}{n} \sum_{i=1}^{n} i_{do}(\theta(i))$
#
# donde n es el número de muestras, en este caso 4.
#
# $I_{DCo} = \frac{1}{4} \cdot  ( 2.866 + 1.311 +0.001 + 1.311 ) =  1.372 A$
#
# $I_{DC1} = \frac{1}{n} \sum_{i=1}^{n} i_{do}(\theta(i)) \cdot \cos(\theta_m(i))$
#
# $I_{DC1} = \frac{1}{n} \cdot  ( 2.866 \cdot \cos(0) + 1.311 \cdot \cos(90) +0.001 \cdot \cos(180) + 1.311 \cdot \cos(270) ) = 1.4327 A$
#
#
# La potencia RMS de DC entonces :
#
# $P_{DC} = VDD \cdot I_{DCo}  = 151.002W$
#
# La potencia RMS de estas dos señales puede ser calculada como:
#
# $P_{DC} = VDD \cdot I_{DCo} + VDD \cdot  \frac{I_{DC1}}{\sqrt{2}} = 151.002W + 111.438W = 262.44 W$
#
#
# ### Potencia de AM
#
#
# La señal de AM esta compuesta por la componente de la poratadora, que este caso puede ser interpretada como la componente cero del espectro de Fourier de la corriente $i_{d1}$ y sus bandas laterales que corresponden a la fundamental (esta componente es la suma de ambas).
#
#
#
# $I_{D1o} = \frac{1}{n} \sum_{i=1}^{n} i_{d1}(\theta_m(i))$
#
#
# donde n es el número de muestras, en este caso 4. Esta es la componete que corresponde a
#
# $I_{D1o} = \frac{1}{4} (4.720 + 2.240 + 0.002 + 2.240) = 2.301 A$
#
#
# $I_{D11} = \frac{1}{4} \sum_{i=1}^{4} i_{d1}(\theta_m(i)) \cdot cos(\theta(i)$
#
# $I_{D11} = \frac{1}{4} (4.720 \cdot \cos(0)  + 2.240 \cdot \cos(90)  + 0.002 \cdot \cos(180)  + 2.240 \cdot \cos(270) ) = 1.179 A$
#
#
#
# #### Potencia de salida
#
# El espectro de AM a la salida entonces esta compouesto por una portadora de valor $I_{ec} =  2.24A$, y sus bandas laterales estan compuesta por dos señales espaciadas por $1 KHz$ con valor de $I_{e1} =  1.17 A$.
#
# Cuya potencia total en la carga es:
#
# $P_o = \frac{i_d(10MHz)^2 \cdot R_c}{2} + \frac{i_d(10MHz-1KHz)^2 \cdot R_c}{2} + \frac{i_d(10MHz+1KHz)^2 \cdot R_c}{2} = 56.079W  + 14.733 W + 14.733 W= 85.545W$

# %% [markdown]
# ## Verificación del espectro
#
#
# La señal de $Vgs$ en el tiempo (usando $fc 100$ y $fm 1$ para ilustrar, no modifica el analisis)
#
# ![ex 2.13](fig/parcial20192811a.png)
#
# Cuyo espectro:
#
# ![ex 2.13](fig/parcial20192811c.png)
#
# La respuesta de corriente del transistor en el tiempo
#
#
# ![ex 2.13](fig/parcial20192811b.png)
#
# Cuyo espectro:
#
# ![ex 2.13](fig/parcial20192811d.png)

# %% [markdown]
# # 7. Se reduce $V_{DD} = 90V$. Sin modificar el filtro de salida, determinar el valor de PEPsi se pretende un indice de modulación del 100 porciento, sin recortes de envolvente.
#
# La nueva tensión de salida sobre $Rc$ en esta condición
#
# $V_{DD} - V_{DSmin} = 90 V - 10 V = 80 V$
#
# $Pep = \frac{80V}{2\cdot Rc} = 151.05 W$

# %% [markdown]
# # 8. En las condiciones del ítem 7, determinar $V_{GG}$  si se mantiene constante $V_s$.
#
# La corriente de $id$ en la condición pico,
#
# $i_{1p} = \frac{80V}{Rc} = \frac{80V}{21} = 3.77A$
#
# En condición de pico $V_{sp} = V_{s} \cdot (1  +  m) = 12.087 V$
#
#
# $$id(\theta) = \frac{1A}{1V}(V_{GG} + Vs \cos(\theta))$$
#
# $$ i_{1p} = \frac{2}{\pi} \int_{0}^{\frac{\theta_c}{2}}   (V_{GG} + V_{sp} \cos(\theta)) \cdot \cos(\theta) d\theta$$
#
# $$ i_{1p} = \frac{2}{\pi} \int_{0}^{\frac{\theta_c}{2}}   (V_{GG} \cdot \cos(\theta) + V_{sp} \cos(\theta) \cdot \cos(\theta))  d\theta$$
#
#
# $$ i_{1p} = \frac{2}{\pi} \int_{0}^{\frac{\theta_c}{2}}   (V_{GG} \cdot \cos(\theta) + \frac{V_{sp}}{2} (1 + \cos(2\theta))  d\theta$$
#
# $$ i_{1p} = \frac{2}{\pi} |  (V_{GG} \cdot \sin(\theta) + \frac{V_{sp}}{2} (\theta + \frac{\sin(2\theta)}{2})  |_{0}^{\frac{\theta_c}{2}}$$
#
#
# $$ i_{1p} = \frac{2}{\pi} [  (V_{GG} \cdot \sin(\frac{\theta_c}{2}) + \frac{V_{sp}}{2} (\frac{\theta_c}{2} + \frac{\sin(2\frac{\theta_c}{2})}{2}) ] $$
#
# $$ i_{1p} = \frac{2}{\pi} [  (V_{GG} \cdot \sin(\frac{\theta_c}{2}) + \frac{V_{sp}}{4} (\theta_c + \sin(\theta_c)) ]= 3.77A$$
#
# $V_{GG} +  V_s \cdot cos(\frac{\theta_c}{2}) = 0V$
#
# Entonces,
#
# $$\frac{2}{\pi} [  -V_s \cdot cos(\frac{\theta_c}{2}) \cdot \sin(\frac{\theta_c}{2}) + \frac{V_{sp}}{4} (\theta_c + \sin(\theta_c)) ]= 3.77A$$
#
# $$\cos(\frac{\theta_c}{2}) \cdot \sin(\frac{\theta_c}{2}) = \frac{\sin(\theta_c)}{2}$$
#
#
#
# $$\frac{2}{\pi} [  (-V_s \cdot \frac{\sin(\theta_c)}{2} + \frac{V_{sp}}{4} (\theta_c + \sin(\theta_c) ]= 3.77A$$
#
# $$\frac{V_{sp} \cdot 2}{\pi} [ \frac{\theta_c}{4}  + \frac{\sin(\theta_c)}{4} - \frac{\sin(\theta_c)}{2}   ]= 3.77A$$
#
# $$\frac{V_{sp} \cdot 2}{\pi} [ \frac{\theta_c}{4}  - \frac{\sin(\theta_c)}{4}  ]= 3.77A$$
#
# $$\frac{V_{sp}}{\pi} [ \theta_c  - \sin(\theta_c)   ]= 3.77A \cdot 2$$
#
#
# $$\theta_c  - \sin(\theta_c)   =  \frac{3.77A \cdot 2 \cdot\pi}{V_{sp}}$$
#
# $$\theta_c  - \sin(\theta_c)   =  1.9574$$
#
# $$\theta_c = 2.53086$$
#
# $$V_{GG} =  -3.6381 V$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy                  # http://scipy.org/
from scipy import signal

from IPython.display import Image  
# %matplotlib inline
params = {'legend.fontsize': 24,
          'figure.figsize': (12, 8),
         'axes.labelsize': 24,
         'axes.titlesize': 24,
         'xtick.labelsize':24,
         'ytick.labelsize':24}
plt.rcParams.update(params) 

from scipy.fftpack import fft, ifft, fftfreq

# %%
## Transformada discreta de Fourier

def myFourierPh(a, x, y, n):
    if a == 0 : 
        yp_o = 0.0
        for i,xi in enumerate(x):
            yp_o += y[i]*1/n
        y_p= yp_o
    else : 
        yp_ac = 0.0
        yp_as = 0.0
        for i,xi in enumerate(x):
            yp_ac += 2/n * y[i]*np.cos(a*xi)
            yp_as += 2/n * y[i]*np.sin(a*xi)
        y_p =  yp_ac + 1j*yp_as
    return y_p

# %%
def vgsi(VGG,Vs,th):
    return VGG+Vs*cos(th)

def vam(amp,m,vm,th):
    return amp*(1+m*vm)*np.cos(th)


def idi(v):
    i = 0.           if (v < 0.)  else 0
    i = (1.)*(v-0.) if (v >= 0   and v < 10) else i
    i = (10.)        if (v >= 10 ) else i
    return i
vgs = np.arange(-5.,20.,0.2)

ids = []
for v in vgs:
    ids.append(idi(v))
#%matplotlib inline
#plt.gca().cla()
plt.plot(vgs,ids,'ro')
#plt.axis([-10, 10, -1, 11])
plt.ylabel('ID')
plt.xlabel('VGS')
plt.rcParams['figure.figsize'] = (20.0, 4.0)
plt.grid()
plt.show()

# %%
### PARAMETROS PARA LOS CALCULOS!!!!

#parametros de la senal AM
fc  = 100#e6    #frecuencia de la portadora
m   = 0.7      #indice de modulacion
fm  = 1 #e3     #frecuencia de la modulante

#tiempo de un periodo de la modulante
Tm  = 1/fm

#Muestreo
fs  =  24*fc

#delta time para el calculo de los armonicos
ds  = 1/(fs)

#parametros del filtro de salida
fo = fc
BW = 2*fm*5
Qc = fo/BW

#parametros del transistor
VDSmin  = 10 
VDD     = 110
Vgs_max = 250

# %% [markdown]
# ## CALCULOS AUXILIARES PUNTO 1

# %%
thc  = 160

Vsm  = 10/(1- np.cos(thc/2*np.pi/180))
VGG = 10 - Vsm
Vs  = Vsm/(1 + m)

print(Vs)

print(VGG)
# Out:
# 7.118460663121196
# -2.1013831273060326

# %% [markdown]
# ## CALCULOS AUXILIARES PUNTO 2

# %%
# Para el calculo de la señal 
nc    = 24
th_c = np.arange(-np.pi,np.pi,2*np.pi/nc)

# Amplitud de la modulante para la condición de pico
vmp  = np.cos(0)

# Señal de la portadora con la modulante
vgs = vam(Vs,m,vmp,th_c)+VGG

# Plot del pulso     
plt.plot(th_c,vgs,'ro')
plt.plot(th_c,vgs)
plt.xlabel('time [rad]')
plt.ylabel('vgs [A]')
plt.grid()
plt.show()

# %%
#Sobre el pulso de corriente de la portadora 
ids = []
for v in vgs:
    ids.append(idi(v))
    
# Plot del pulso     
plt.plot(th_c,ids,'ro')
plt.plot(th_c,ids)

plt.xlabel('time [rad]')
plt.ylabel('ids [A]')
plt.grid()

# %%
# Calculos !
print('|th      |vgs      |ids      |ids.cos(th)|')
for i,p in enumerate(th_c):
    if p  >= 0 :
        print('|{:8.2f}| {:8.2f}| {:8.2f}| {:10.2f}|'.format( 
            p*180/np.pi, vgs[i], ids[i], ids[i]*np.cos(p)   ) ) =
        
# Continua
idpo  1/nc * np.sum(ids) 

# primer arminico
idp1 = 2/nc * np.sum([ids[i]*np.cos(th) for i,th in enumerate(th_c)] ) 


print('idco= {:1.2f} A, idc1={:1.2f} A'.format(idpo,idp1) )
# Out:
# |th      |vgs      |ids      |ids.cos(th)|
# |    0.00|    10.00|    10.00|      10.00|
# |   15.00|     9.59|     9.59|       9.26|
# |   30.00|     8.38|     8.38|       7.26|
# |   45.00|     6.46|     6.46|       4.56|
# |   60.00|     3.95|     3.95|       1.97|
# |   75.00|     1.03|     1.03|       0.27|
# |   90.00|    -2.10|     0.00|      -0.00|
# |  105.00|    -5.23|     0.00|      -0.00|
# |  120.00|    -8.15|     0.00|      -0.00|
# |  135.00|   -10.66|     0.00|      -0.00|
# |  150.00|   -12.58|     0.00|      -0.00|
# |  165.00|   -13.79|     0.00|      -0.00|
# idco= 2.87 A, idc1=4.72 A

# %%
# La salida tiene una escursión de (VDD-VDSmin)

Vdp = VDD-VDSmin

Rc = Vdp/idp1

print('Rc= {:1.2f} ohm'.format(Rc))
# Out:
# Rc= 21.18 ohm

# %% [markdown]
# ## CALCULOS AUXILIARES PUNTO 3

# %%
Pop = Rc*idp1**2/2


Pdcp = VDD*idpo 



print(VDD,idpo,Pdcp)

Pmosp = Pdcp  - Pop
print(Pop,Pdcp, Pmosp)
# Out:
# 110 2.8668298441054643 315.35128285160107
# 236.02795513412556 315.35128285160107 79.32332771747551

# %% [markdown]
# ## CALCULOS AUXILIARES PUNTO 4

# %%
thc =  (np.arccos(2.1/(7.11)))*2

print(thc*180/np.pi)

thc =  (np.arccos(2.1/(7.11*0.3)))*2

print(thc*180/np.pi)
# Out:
# 145.64191035419245
# 20.183230651096757

# %% [markdown]
# ## CALCULOS AUXILIARES PUNTO 5

# %%
# Para el calculo de la señal 
nc    = 24
th_c = np.arange(-np.pi,np.pi,2*np.pi/nc)

# Amplitud de la modulante para la condición de portadora
vmp  = np.cos(np.pi)

# Señal de la portadora con la modulante
vgs = vam(Vs,m,vmp,th_c)+VGG

# Plot del pulso     
plt.plot(th_c,vgs,'ro')
plt.plot(th_c,vgs)
plt.xlabel('time [rad]')
plt.ylabel('vgs [A]')
plt.grid()
plt.show()

#Sobre el pulso de corriente de la portadora 
ids = []
for v in vgs:
    ids.append(idi(v))
    
# Plot del pulso     
plt.plot(th_c,ids,'ro')
plt.plot(th_c,ids)
plt.xlabel('time [rad]')
plt.ylabel('ids [A]')
plt.grid()
plt.show()


# Calculos !
print('|th      |vgs      |ids      |ids.cos(th)|')
for i,p in enumerate(th_c):
    if p  >= 0 :
        print('|{:8.2f}| {:8.2f}| {:8.2f}| {:10.2f}|'.format( 
            p*180/np.pi, vgs[i], ids[i], ids[i]*np.cos(p)   ) ) 
        
# Continua
idvo = 1/nc * np.sum(ids) 

# primer arminico
idv1 = 2/nc * np.sum([ids[i]*np.cos(th) for i,th in enumerate(th_c)] ) 


print('idvo= {:1.3f} A, idv1={:1.3f} A'.format(idvo,idv1) )   

Vdv = Rc * idv1

print(Vdv)

mo = (Vdp- Vdv) / (Vdp+ Vdv)


print(mo)


Pov = Rc*idv1**2/2


Pdcv = VDD*idvo

Pmosv = Pdcv  - Pov
print(Pov,Pdcv, Pmosv)
# Out:
# |th      |vgs      |ids      |ids.cos(th)|
# |    0.00|     0.03|     0.03|       0.03|
# |   15.00|    -0.04|     0.00|       0.00|
# |   30.00|    -0.25|     0.00|       0.00|
# |   45.00|    -0.59|     0.00|       0.00|
# |   60.00|    -1.03|     0.00|       0.00|
# |   75.00|    -1.55|     0.00|       0.00|
# |   90.00|    -2.10|     0.00|      -0.00|
# |  105.00|    -2.65|     0.00|      -0.00|
# |  120.00|    -3.17|     0.00|      -0.00|
# |  135.00|    -3.61|     0.00|      -0.00|
# |  150.00|    -3.95|     0.00|      -0.00|
# |  165.00|    -4.16|     0.00|      -0.00|
# idvo= 0.001 A, idv1=0.003 A
# 0.06029489107712847
# 0.9987948288350985
# 8.580734682008625e-05 0.1565440783056641 0.15645827095884401

# %% [markdown]
# ## CALCULOS AUXILIARES PUNTO 6

# %%
# Para el calculo de la señal 
nc    = 24
th_c = np.arange(-np.pi,np.pi,2*np.pi/nc)

# Amplitud de la modulante para la condición de portadora
vmp  = np.cos(np.pi/2)

# Señal de la portadora con la modulante
vgs = vam(Vs,m,vmp,th_c)+VGG

# Plot del pulso     
plt.plot(th_c,vgs,'ro')
plt.plot(th_c,vgs)
plt.xlabel('time [rad]')
plt.ylabel('vgs [A]')
plt.grid()
plt.show()

#Sobre el pulso de corriente de la portadora 
ids = []
for v in vgs:
    ids.append(idi(v))
    
# Plot del pulso     
plt.plot(th_c,ids,'ro')
plt.plot(th_c,ids)
plt.xlabel('time [rad]')
plt.ylabel('ids [A]')
plt.grid()
plt.show()


# Calculos !
print('|th      |vgs      |ids      |ids.cos(th)|')
for i,p in enumerate(th_c):
    if p  >= 0 :
        print('|{:8.2f}| {:8.2f}| {:8.2f}| {:10.2f}|'.format( 
            p*180/np.pi, vgs[i], ids[i], ids[i]*np.cos(p)   ) ) 
        
# Continua
idco = 1/nc * np.sum(ids) 

# primer arminico
idc1 = 2/nc * np.sum([ids[i]*np.cos(th) for i,th in enumerate(th_c)] ) 


print('idco= {:1.2f} A, idc1={:1.2f} A'.format(idco,idc1) )  

Poc = Rc*idc1**2/2


Pdcc = VDD*idco 

Pmosc = Pdcc  - Poc
print('Potencias:')
print(Poc,Pdcc, Pmosc)


print('Corriente:')
print(idp1  ,idc1 ,idv1)
# Out:
# |th      |vgs      |ids      |ids.cos(th)|
# |    0.00|     5.02|     5.02|       5.02|
# |   15.00|     4.77|     4.77|       4.61|
# |   30.00|     4.06|     4.06|       3.52|
# |   45.00|     2.93|     2.93|       2.07|
# |   60.00|     1.46|     1.46|       0.73|
# |   75.00|    -0.26|     0.00|       0.00|
# |   90.00|    -2.10|     0.00|      -0.00|
# |  105.00|    -3.94|     0.00|      -0.00|
# |  120.00|    -5.66|     0.00|      -0.00|
# |  135.00|    -7.13|     0.00|      -0.00|
# |  150.00|    -8.27|     0.00|      -0.00|
# |  165.00|    -8.98|     0.00|      -0.00|
# idco= 1.31 A, idc1=2.24 A
# Potencias:
# 53.15904992773151 144.25052734383019 91.09147741609868
# Corriente:
# 3.7696772453479275 2.240269791905908 0.002846255969193893

# %%
# Tensión de salida a la entrada del filtro PI

vdo = VDD + Rc*idc1*np.cos(th_c)

plt.plot(th_c, vdo)

plt.xlabel('time [rad]')
plt.ylabel('vdo [A]')
plt.grid()

# %%
Poc = Rc*idc1**2/2


Pdcp = VDD*idco 

th  = [0,np.pi/2,np.pi,3*np.pi/2]
idc = [idpo,idco, idvo, idco]
id1 = [idp1,idc1, idv1, idc1]

# Continua
iddco = 1/4 * np.sum([idc[i]            for i,th in enumerate(th)] ) 
iddc1 = 2/4 * np.sum([idc[i]*np.cos(th) for i,th in enumerate(th)] ) 


print('DC')
print(idc)
print(iddco, iddc1)

print(iddco*VDD)
print(iddc1*VDD/2**(1/2))

# Señal
id1o = 1/4 * np.sum([id1[i]            for i,th in enumerate(th)] ) 
id11 = 1/4 * np.sum([id1[i]*np.cos(th) for i,th in enumerate(th)] ) 

print('AM')
print(id1)
print(id1o, id11)

print(id1o**2*Rc/2)
print(id11**2*Rc/2)
print(id11**2*Rc/2)
# Out:
# DC
# [2.204670575334971, 1.3113684303984563, 0.0014231279845969465, 1.3113684303984563]
# 1.2072076410291201 1.1016237236751867
# 132.7928405132032
# 85.68621658593699
# AM
# [3.7696772453479275, 2.240269791905908, 0.002846255969193893, 2.240269791905908]
# 2.0632657712822344 0.9417077473446833
# 45.09069318214603
# 9.393097958513604
# 9.393097958513604

# %%
def vam(amp,m,vm,th):
    return amp*(1+m*vm)*np.cos(th)


time = np.arange(0,Tm,ds)
vgs = []
for t in time:
    vm =  np.cos( 2*np.pi*fm*t)
    vgs.append(vam(Vs, m ,vm,2*np.pi*fc*t)+ VGG)

plt.plot(time,vgs)
plt.xlabel('time [seg]')
plt.ylabel('VAM [V]')
plt.show()

# %%
# Transformada de Fourier
Y = fft(vgs) / len(vgs)  # Normalizada
frq = fftfreq(len(vgs), ds)  # Recuperamos las frecuencias

# Plot de la transformada
plt.stem(frq, np.abs(Y)*2 )  #
plt.xlim([-1,120])
plt.xlabel('$Frecuencia/Hz$')
plt.ylabel('$Abs(VGS)$')
plt.grid()
plt.show()
# Out:
# /home/aalmela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
ids = []
for x,t in enumerate(time):
    ids.append(idi(vgs[x]))

plt.plot(time,ids)
plt.xlabel('time [seg]')
plt.ylabel('ids [A]')
# Out:
# Text(0, 0.5, 'ids [A]')

# %%
# Transformada de Fourier
Idd = fft(ids) / len(ids)  # Normalizada
frq = fftfreq(len(ids), ds)  # Recuperamos las frecuencias

# Plot de la transformada
plt.stem(frq, 20*np.log10(np.abs(Idd)*2) )  #
plt.xlim([94,104])
plt.xlabel('$Frecuencia/Hz$')
plt.ylabel('$Abs(Id)$')
plt.grid()
plt.show()
# Out:
# /home/aalmela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
# Plot de la transformada
plt.stem(frq, np.abs(Idd)*2 )  #
plt.xlim([90,310])
plt.xlabel('$Frecuencia/Hz$')
plt.ylabel('$Abs(Id)$')
plt.grid()
plt.show()

print(  [np.abs(Idd[i])*2 for i in [97,98,99,100,101,102,103,104]])
# Out:
# /home/aalmela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# [0.014555328664498244, 0.027497878805574655, 1.2016067311323098, 2.281229021729551, 1.201560710539243, 0.02750757793420464, 0.014543718728247028, 0.008720373424303715]

# %%
# filtro LC 

def filtroLC(f,fo,Qc):
    if f == 0 : Av = 0 
    else      : Av = 1/(1 + 1j*(Qc*((f/fo) -(fo/f))))
    return Av

#Vo = [idf for fr,idf in zip(frq,Idd)]
Vo = [Rc*idf*filtroLC(fr,fc,Qc) for fr,idf in zip(frq,Idd)]
#Vo = [Rc*idf for fr,idf in zip(frq,Idd)]

# Plot de la transformada
plt.stem(frq, np.abs(Vo)*2 )  #
plt.xlim([0,310])
plt.xlabel('$Frecuencia/Hz$')
plt.ylabel('$Abs(Vd)$')
plt.grid()
plt.show()
# Out:
# /home/aalmela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   del sys.path[0]

# %%
# detector sincronico 
Vot    = ifft(Vo)*len(Vo)
plt.plot(Vot)
# Out:
# 99.19712024829784

# %%
# Out:
# (24.162699503467895+5.778120790775339e-13j)

# %% [markdown]
# ### Distorsión armonica de la señal envolvente.
#
# $THD = \frac{\sum_{i =2}^{\inf} P_i }{P_1}$

# %% [markdown]
# # 7.

# %% [markdown]
# # Calculos auxilares punto 7

# %%
Pepp = 80**2/Rc/2
print(Pepp)
# Out:
# 151.05789128584036

# %% [markdown]
# # Calculos auxilares punto 8

# %%
print(3.77*2*np.pi/(Vs*(1+m)))
print(4.72*2*np.pi/(Vs*(1+m)))

print(160*np.pi/180)

print(Vs)
print(- np.cos(2.53086/2)*(Vs*(1+m)) )
# Out:
# 1.9574298539988704
# 2.450681408720071
# 2.792526803190927
# 7.118460663121196
# -3.638190981422633

# %%
# Para el calculo de la señal 
VGGb = -3.6381

nc    = 24
th_c = np.arange(-np.pi,np.pi,2*np.pi/nc)

# Amplitud de la modulante para la condición de pico
vmp  = np.cos(0)

# Señal de la portadora con la modulante
vgs = vam(Vs,m,vmp,th_c)+VGGb

# Plot del pulso     
plt.plot(th_c,vgs,'ro')
plt.plot(th_c,vgs)
plt.xlabel('time [rad]')
plt.ylabel('vgs [A]')
plt.grid()
plt.show()


#Sobre el pulso de corriente de la portadora 
ids = []
for v in vgs:
    ids.append(idi(v))
    
# Plot del pulso     
plt.plot(th_c,ids,'ro')
plt.plot(th_c,ids)
plt.xlabel('time [rad]')
plt.ylabel('ids [A]')
plt.grid()

# Calculos !
print('|th      |vgs      |ids      |ids.cos(th)|')
for i,p in enumerate(th_c):
    if p  >= 0 :
        print('|{:8.2f}| {:8.2f}| {:8.2f}| {:10.2f}|'.format( 
            p*180/np.pi, vgs[i], ids[i], ids[i]*np.cos(p)   ) ) 
        
# Continua
idpo = 1/nc * np.sum(ids) 

# primer arminico
idp1 = 2/nc * np.sum([ids[i]*np.cos(th) for i,th in enumerate(th_c)] ) 


print('idco= {:1.2f} A, idc1={:1.2f} A'.format(idpo,idp1) )
# Out:
# |th      |vgs      |ids      |ids.cos(th)|
# |    0.00|     8.46|     8.46|       8.46|
# |   15.00|     8.05|     8.05|       7.78|
# |   30.00|     6.84|     6.84|       5.93|
# |   45.00|     4.92|     4.92|       3.48|
# |   60.00|     2.41|     2.41|       1.21|
# |   75.00|    -0.51|     0.00|       0.00|
# |   90.00|    -3.64|     0.00|      -0.00|
# |  105.00|    -6.77|     0.00|      -0.00|
# |  120.00|    -9.69|     0.00|      -0.00|
# |  135.00|   -12.20|     0.00|      -0.00|
# |  150.00|   -14.12|     0.00|      -0.00|
# |  165.00|   -15.33|     0.00|      -0.00|
# idco= 2.20 A, idc1=3.77 A

# %%
thcc   = 160*np.pi/180

iddd   =  4/np.pi*(VGG*np.sin(thcc/2)+ Vs/2*((thcc/2) + np.sin(thcc)/2 ))
print(VGG,Vs,thc*180/np.pi)
print(iddd)
# Out:
# -2.1013831273060326 7.118460663121196 20.183230651096757
# 4.4675796959759495

# %%
# Para el calculo de la señal 
nc    = 100
th_c = np.arange(0,2*np.pi,2*np.pi/nc)

# Amplitud de la modulante para la condición de pico
vmp  = np.cos(0)

# Señal de la portadora con la modulante
vgs = vam(Vs,m,vmp,th_c)+VGG

#Sobre el pulso de corriente de la portadora 
ids = []
for v in vgs:
    ids.append(idi(v))
    

# Transformada de Fourier
Y = fft(ids) / len(ids)  # Normalizada
frq = fftfreq(len(ids), 1/24)  # Recuperamos las frecuencias
print((Y[0:2]))
# Plot de la transformada
plt.stem(frq, np.abs(Y) )  #
#plt.xlim([-1,120])
plt.xlabel('$Frecuencia/Hz$')
plt.ylabel('$Abs(VGS)$')
plt.grid()
plt.show()
# Out:
# [2.85956899+0.00000000e+00j 2.35982513+3.12166563e-16j]
# /home/aalmela/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
